# %%
import pandas as pd

# %%
df1 = pd.read_csv('store_member_total.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   500 non-null    int64
#  1   회원번호         500 non-null    int64
#  2   회원상태         499 non-null    object
#  3   성별           497 non-null    object
#  4   결혼유무         361 non-null    object
#  5   구매금액(clean)  500 non-null    float64
#  6   구매수량(clean)  500 non-null    float64
#  7   총방문횟수        500 non-null    int64
#  8   간식(%)        500 non-null    float64
#  9   건강(%)        500 non-null    float64
#  10  과실(%)        500 non-null    float64
#  11  생활용품(%)      500 non-null    float64
#  12  서류(%)        500 non-null    float64
#  13  수산(%)        500 non-null    float64
#  14  양념/가루(%)     500 non-null    float64
#  15  음료(%)        500 non-null    float64
#  16  잡곡(%)        500 non-null    float64
#  17  주곡(%)        500 non-null    float64
# ...

# %%
# !pip install --user pandas_profiling

# %%
import pandas_profiling

# %%
report_df1 = df1.profile_report()

# %%
report_df1.to_file('report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(
# ...

# %%
df2 = pd.read_csv('01_Contract_Data.csv')

# %%
report_df2 = df2.profile_report()
report_df2.to_file('report2.html')
# Out:
# ...
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 47116 (\N{HANGUL SYLLABLE REN}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 53448 (\N{HANGUL SYLLABLE TAL}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 47716 (\N{HANGUL SYLLABLE MEM}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   plt.savefig(
# /Users/jm/.local/lib/python3.9/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 49901 (\N{HANGUL SYLLABLE SIB}) missing from current font.
#   plt.savefig(
# ...
